# %% [markdown]
# <a href="https://colab.research.google.com/github/JeongeunL/AI_ML/blob/main/practice/Practice_230927.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_03
# Out:
# /content/drive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_03

# %%
import pandas as pd

# %%
# 데이터 불러오기 (long df)
long_df = pd.read_csv(
    'data/long_data.csv', usecols=['date', 'datatype', 'value']
).rename(
    columns={'value': 'temp_C'}
).assign(
    date=lambda x: pd.to_datetime(x.date),
    temp_F=lambda x: (x.temp_C * 9/5) + 32
)
long_df.head()
# Out:
#   datatype       date  temp_C  temp_F
# 0     TMAX 2018-10-01    21.1   69.98
# 1     TMIN 2018-10-01     8.9   48.02
# 2     TOBS 2018-10-01    13.9   57.02
# 3     TMAX 2018-10-02    23.9   75.02
# 4     TMIN 2018-10-02    13.9   57.02

# %%
# Pivoting
pivoted_df = long_df.pivot(
    index='date', columns='datatype', values=['temp_C', 'temp_F']
)
pivoted_df.head()
# Out:
#            temp_C             temp_F
# datatype     TMAX  TMIN  TOBS   TMAX   TMIN   TOBS
# date
# 2018-10-01   21.1   8.9  13.9  69.98  48.02  57.02
# 2018-10-02   23.9  13.9  17.2  75.02  57.02  62.96
# 2018-10-03   25.0  15.6  16.1  77.00  60.08  60.98
# 2018-10-04   22.8  11.7  11.7  73.04  53.06  53.06
# 2018-10-05   23.3  11.7  18.9  73.94  53.06  66.02

# %%
# Unstack
multi_index_df = long_df.set_index(['date', 'datatype'])
multi_index_df.head().index
# Out:
# MultiIndex([('2018-10-01', 'TMAX'),
#             ('2018-10-01', 'TMIN'),
#             ('2018-10-01', 'TOBS'),
#             ('2018-10-02', 'TMAX'),
#             ('2018-10-02', 'TMIN')],
#            names=['date', 'datatype'])

# %%
multi_index_df.head()
# Out:
#                      temp_C  temp_F
# date       datatype
# 2018-10-01 TMAX        21.1   69.98
#            TMIN         8.9   48.02
#            TOBS        13.9   57.02
# 2018-10-02 TMAX        23.9   75.02
#            TMIN        13.9   57.02

# %%
unstacked_df = multi_index_df.unstack()
unstacked_df.head()
# Out:
#            temp_C             temp_F
# datatype     TMAX  TMIN  TOBS   TMAX   TMIN   TOBS
# date
# 2018-10-01   21.1   8.9  13.9  69.98  48.02  57.02
# 2018-10-02   23.9  13.9  17.2  75.02  57.02  62.96
# 2018-10-03   25.0  15.6  16.1  77.00  60.08  60.98
# 2018-10-04   22.8  11.7  11.7  73.04  53.06  53.06
# 2018-10-05   23.3  11.7  18.9  73.94  53.06  66.02

# %%
# 데이터 불러오기 (wide df)
wide_df = pd.read_csv('data/wide_data.csv')
wide_df.head()
# Out:
#          date  TMAX  TMIN  TOBS
# 0  2018-10-01  21.1   8.9  13.9
# 1  2018-10-02  23.9  13.9  17.2
# 2  2018-10-03  25.0  15.6  16.1
# 3  2018-10-04  22.8  11.7  11.7
# 4  2018-10-05  23.3  11.7  18.9

# %%
# Melting
melted_df = wide_df.melt(
    id_vars='date',
    value_vars=['TMAX', 'TMIN', 'TOBS'],
    value_name='temp_C',
    var_name='measurement'
)
melted_df.head()
# Out:
#          date measurement  temp_C
# 0  2018-10-01        TMAX    21.1
# 1  2018-10-02        TMAX    23.9
# 2  2018-10-03        TMAX    25.0
# 3  2018-10-04        TMAX    22.8
# 4  2018-10-05        TMAX    23.3

# %%
# Stack
wide_df.set_index('date', inplace=True)
wide_df.head()
# Out:
#             TMAX  TMIN  TOBS
# date
# 2018-10-01  21.1   8.9  13.9
# 2018-10-02  23.9  13.9  17.2
# 2018-10-03  25.0  15.6  16.1
# 2018-10-04  22.8  11.7  11.7
# 2018-10-05  23.3  11.7  18.9

# %%
stacked_series = wide_df.stack()
stacked_series.head()
# Out:
# date
# 2018-10-01  TMAX    21.1
#             TMIN     8.9
#             TOBS    13.9
# 2018-10-02  TMAX    23.9
#             TMIN    13.9
# dtype: float64

# %%
stacked_df = stacked_series.to_frame('values')
stacked_df.head()
# Out:
#                  values
# date
# 2018-10-01 TMAX    21.1
#            TMIN     8.9
#            TOBS    13.9
# 2018-10-02 TMAX    23.9
#            TMIN    13.9

# %%
######### Tasks for today 2 ############

# %%
# 데이터 불러오기 (dirty df)
dirty_df = pd.read_csv('data/dirty_data.csv')
dirty_df.head()
# Out:
#                   date            station  PRCP  SNOW  SNWD    TMAX  TMIN  \
# 0  2018-01-01T00:00:00                  ?   0.0   0.0  -inf  5505.0 -40.0
# 1  2018-01-01T00:00:00                  ?   0.0   0.0  -inf  5505.0 -40.0
# 2  2018-01-01T00:00:00                  ?   0.0   0.0  -inf  5505.0 -40.0
# 3  2018-01-02T00:00:00  GHCND:USC00280907   0.0   0.0  -inf    -8.3 -16.1
# 4  2018-01-03T00:00:00  GHCND:USC00280907   0.0   0.0  -inf    -4.4 -13.9
#
#    TOBS  WESF inclement_weather
# 0   NaN   NaN               NaN
# 1   NaN   NaN               NaN
# 2   NaN   NaN               NaN
# 3 -12.2   NaN             False
# 4 -13.3   NaN             False

# %%
# Finding problematic data - 1) 기초통계량 보기
dirty_df.describe()
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:4527: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
#              PRCP        SNOW   SNWD         TMAX        TMIN        TOBS  \
# count  765.000000  577.000000  577.0   765.000000  765.000000  398.000000
# mean     5.360392    4.202773    NaN  2649.175294  -15.914379    8.632161
# std     10.002138   25.086077    NaN  2744.156281   24.242849    9.815054
# min      0.000000    0.000000   -inf   -11.700000  -40.000000  -16.100000
# 25%      0.000000    0.000000    NaN    13.300000  -40.000000    0.150000
# 50%      0.000000    0.000000    NaN    32.800000  -11.100000    8.300000
# 75%      5.800000    0.000000    NaN  5505.000000    6.700000   18.300000
# max     61.700000  229.000000    inf  5505.000000   23.900000   26.100000
#
#             WESF
# count  11.000000
# mean   16.290909
# std     9.489832
# min     1.800000
# 25%     8.600000
# 50%    19.300000
# 75%    24.900000
# ...

# %%
# Finding problematic data - 2) 데이터 정보 보기 (non-null 개수)
dirty_df.info()

# SNOW, SNWD, TOBS, WESF, Inclement_weather에 결측치
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 765 entries, 0 to 764
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               765 non-null    object
#  1   station            765 non-null    object
#  2   PRCP               765 non-null    float64
#  3   SNOW               577 non-null    float64
#  4   SNWD               577 non-null    float64
#  5   TMAX               765 non-null    float64
#  6   TMIN               765 non-null    float64
#  7   TOBS               398 non-null    float64
#  8   WESF               11 non-null     float64
#  9   inclement_weather  408 non-null    object
# dtypes: float64(7), object(3)
# memory usage: 59.9+ KB

# %%
# Finding problematic data - 3) 특정 열에 결측치 있는지 확인 (.isna())
dirty_df[dirty_df.SNOW.isna() | dirty_df.SNWD.isna()]
# Out:
#                     date station  PRCP  SNOW  SNWD    TMAX  TMIN  TOBS  WESF  \
# 9    2018-01-05T00:00:00       ?   0.3   NaN   NaN  5505.0 -40.0   NaN   NaN
# 10   2018-01-05T00:00:00       ?   0.3   NaN   NaN  5505.0 -40.0   NaN   NaN
# 21   2018-01-12T00:00:00       ?   0.5   NaN   NaN  5505.0 -40.0   NaN   NaN
# 22   2018-01-12T00:00:00       ?   0.5   NaN   NaN  5505.0 -40.0   NaN   NaN
# 25   2018-01-13T00:00:00       ?  17.5   NaN   NaN  5505.0 -40.0   NaN   NaN
# ..                   ...     ...   ...   ...   ...     ...   ...   ...   ...
# 754  2018-12-28T00:00:00       ?  11.4   NaN   NaN  5505.0 -40.0   NaN   NaN
# 756  2018-12-28T00:00:00       ?  11.4   NaN   NaN  5505.0 -40.0   NaN   NaN
# 757  2018-12-29T00:00:00       ?  21.3   NaN   NaN  5505.0 -40.0   NaN   NaN
# 758  2018-12-29T00:00:00       ?  21.3   NaN   NaN  5505.0 -40.0   NaN   NaN
# 759  2018-12-30T00:00:00       ?   0.0   NaN   NaN  5505.0 -40.0   NaN   NaN
#
#     inclement_weather
# ...

# %%
# Finding problematic data - 4) 특정 열에 결측치 있는지 확인 (.isna())
contain_nulls = dirty_df[
    dirty_df.SNOW.isna() | dirty_df.SNWD.isna() | dirty_df.TOBS.isna()
    | dirty_df.WESF.isna() | dirty_df.inclement_weather.isna()
]
contain_nulls.shape[0] # 결측치 개수?
# Out:
# 765

# %%
contain_nulls.head(10) # 결측치를 포함하고 있는 행들
# Out:
#                   date            station  PRCP   SNOW  SNWD    TMAX  TMIN  \
# 0  2018-01-01T00:00:00                  ?   0.0    0.0  -inf  5505.0 -40.0
# 1  2018-01-01T00:00:00                  ?   0.0    0.0  -inf  5505.0 -40.0
# 2  2018-01-01T00:00:00                  ?   0.0    0.0  -inf  5505.0 -40.0
# 3  2018-01-02T00:00:00  GHCND:USC00280907   0.0    0.0  -inf    -8.3 -16.1
# 4  2018-01-03T00:00:00  GHCND:USC00280907   0.0    0.0  -inf    -4.4 -13.9
# 5  2018-01-03T00:00:00  GHCND:USC00280907   0.0    0.0  -inf    -4.4 -13.9
# 6  2018-01-03T00:00:00  GHCND:USC00280907   0.0    0.0  -inf    -4.4 -13.9
# 7  2018-01-04T00:00:00                  ?  20.6  229.0   inf  5505.0 -40.0
# 8  2018-01-04T00:00:00                  ?  20.6  229.0   inf  5505.0 -40.0
# 9  2018-01-05T00:00:00                  ?   0.3    NaN   NaN  5505.0 -40.0
#
#    TOBS  WESF inclement_weather
# 0   NaN   NaN               NaN
# 1   NaN   NaN               NaN
# 2   NaN   NaN               NaN
# ...

# %%
# Finding problematic data - 4) 특정 열에 있는 결측치 개수 확인 (.isna()) (2)
dirty_df[dirty_df.inclement_weather.isna()].shape[0]

# %%
# Finding problematic data - 5) inf, -inf 값 있는지 확인
import numpy as np

dirty_df.SNWD.isin([-np.inf, np.inf])
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 760    True
# 761    True
# 762    True
# 763    True
# 764    True
# Name: SNWD, Length: 765, dtype: bool

# %%
# Finding problematic data - 6) 열별 inf, -inf 개수 확인
def get_inf_count(df):
    """Find the number of inf/-inf values per column in the dataframe"""
    return {
        col: dirty_df[dirty_df[col].isin([np.inf, -np.inf])].shape[0] for col in dirty_df.columns
    }

get_inf_count(dirty_df)
# Out:
# {'date': 0,
#  'station': 0,
#  'PRCP': 0,
#  'SNOW': 0,
#  'SNWD': 577,
#  'TMAX': 0,
#  'TMIN': 0,
#  'TOBS': 0,
#  'WESF': 0,
#  'inclement_weather': 0}

# %%
# Finding problematic data - 7) inf, -inf가 있는 열과 관련이 있는 열 데이터의 경향성 보기
dirty_df[dirty_df.SNWD == np.inf].SNOW.describe()
# Out:
# count     24.000000
# mean     101.041667
# std       74.498018
# min       13.000000
# 25%       25.000000
# 50%      120.500000
# 75%      152.000000
# max      229.000000
# Name: SNOW, dtype: float64

# %%
pd.DataFrame({
    'np.inf Snow Depth': dirty_df[dirty_df.SNWD == np.inf].SNOW.describe(), # when SNWD is inf
    '-np.inf Snow Depth': dirty_df[dirty_df.SNWD == -np.inf].SNOW.describe() # when SNWD is -inf
}).T
# 이 경향성을 바탕으로 inf, -inf 값을 바꿔야 한다.
# Out:
#                     count        mean        std   min   25%    50%    75%  \
# np.inf Snow Depth    24.0  101.041667  74.498018  13.0  25.0  120.5  152.0
# -np.inf Snow Depth  553.0    0.000000   0.000000   0.0   0.0    0.0    0.0
#
#                       max
# np.inf Snow Depth   229.0
# -np.inf Snow Depth    0.0

# %%
# Finding problematic data - 8) 빠진 데이터 없는지 확인 (date, station)
dirty_df.describe(include='object')
# Out:
#                   station inclement_weather
# count                 765               408
# unique                  2                 2
# top     GHCND:USC00280907             False
# freq                  398               384

# %%
# Finding problematic data - 9) 중복되는 데이터 개수 확인
dirty_df[dirty_df.duplicated()].shape[0]
# Out:
# 284

# %%
dirty_df.duplicated()
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 760    False
# 761     True
# 762     True
# 763    False
# 764     True
# Length: 765, dtype: bool

# %%
dirty_df[-dirty_df.duplicated(keep='first')] # 중복되는 데이터 제거
# Out:
#                     date            station  PRCP   SNOW  SNWD    TMAX  TMIN  \
# 0    2018-01-01T00:00:00                  ?   0.0    0.0  -inf  5505.0 -40.0
# 3    2018-01-02T00:00:00  GHCND:USC00280907   0.0    0.0  -inf    -8.3 -16.1
# 4    2018-01-03T00:00:00  GHCND:USC00280907   0.0    0.0  -inf    -4.4 -13.9
# 7    2018-01-04T00:00:00                  ?  20.6  229.0   inf  5505.0 -40.0
# 9    2018-01-05T00:00:00                  ?   0.3    NaN   NaN  5505.0 -40.0
# ..                   ...                ...   ...    ...   ...     ...   ...
# 755  2018-12-28T00:00:00  GHCND:USC00280907  11.7    0.0  -inf     6.1  -1.7
# 757  2018-12-29T00:00:00                  ?  21.3    NaN   NaN  5505.0 -40.0
# 759  2018-12-30T00:00:00                  ?   0.0    NaN   NaN  5505.0 -40.0
# 760  2018-12-31T00:00:00  GHCND:USC00280907   0.0    0.0  -inf     3.3  -3.3
# 763  2018-12-31T00:00:00                  ?   0.0    0.0  -inf  5505.0 -40.0
#
#      TOBS  WESF inclement_weather
# ...

# %%
# Mitigating data
dirty_df[dirty_df.WESF.notna()].station.unique()
# Out:
# array(['?'], dtype=object)

# %%
# 1. make the date a datetime
dirty_df.date = pd.to_datetime(dirty_df.date)

# 2. save this information for later
station_qm_wesf = dirty_df[dirty_df.station == '?'].drop_duplicates('date').set_index('date').WESF

# 3. sort ? to the bottom
dirty_df.sort_values('station', ascending=False, inplace=True)

# 4. drop duplicates based on the date column keeping the first occurrence
# which will be the valid station if it has data
df_deduped = dirty_df.drop_duplicates('date')

# 5. remove the station column because we are done with it
df_deduped = df_deduped.drop(columns='station').set_index('date').sort_index()

# 6. take valid station's WESF and fall back on station ? if it is null
df_deduped = df_deduped.assign(
    WESF=lambda x: x.WESF.combine_first(station_qm_wesf)
) # WESF 값이 NaN이라면, station_qm_wesf 값으로 바꾼다.

df_deduped.shape
# Out:
# (324, 8)

# %%
df_deduped.head()
# Out:
#             PRCP   SNOW  SNWD    TMAX  TMIN  TOBS  WESF inclement_weather
# date
# 2018-01-01   0.0    0.0  -inf  5505.0 -40.0   NaN   NaN               NaN
# 2018-01-02   0.0    0.0  -inf    -8.3 -16.1 -12.2   NaN             False
# 2018-01-03   0.0    0.0  -inf    -4.4 -13.9 -13.3   NaN             False
# 2018-01-04  20.6  229.0   inf  5505.0 -40.0   NaN  19.3              True
# 2018-01-05  14.2  127.0   inf    -4.4 -13.9 -13.9   NaN              True
